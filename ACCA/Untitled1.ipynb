# %%
import pickle

ACCA_Firms = pickle.load(open('/home/de-admin/Documents/Webscraping/ACCA_Firms.p','rb'))

ACCA_Websites = []

for i in ACCA_Firms:
    ACCA_Websites.append(i[6])

def orderedUniques(seq, idfun=None): 
    # order preserving
    if idfun is None:
        def idfun(x): return x
    seen = {}
    result = []
    for item in seq:
        marker = idfun(item)
        # in old Python versions:
        # if seen.has_key(marker)
        # but in new ones:
        if marker in seen: continue
        seen[marker] = 1
        result.append(item)
    return result

ACCA_Websites = orderedUniques(filter(None, ACCA_Websites))

# %%
ACCA_Websites[400:500]
# Out:
# ['http://www.raclement.co.uk',
#  'http://www.joshuaefue.co.uk',
#  'http://www.wilsonfield.co.uk',
#  'http://www.saffery.com',
#  'http://www.carletonbusinessservices.co.uk',
#  'http://www.danmirr.co.uk',
#  'http://www.lermer.co.uk',
#  'http://www.completeaccounts.co.uk',
#  'http://www.arassociates.info',
#  'http://www.mfw.co.uk',
#  'http://www.rgaaccounting.co.uk',
#  'http://www.weaverrose.com',
#  'http://www.alphaaccounts.co.uk',
#  'http://www.eclhws.com',
#  'http://www.usherspiby.com',
#  'http://www.bmcooper.co.uk',
#  'http://www.ktcselby.co.uk',
#  'http://www.essaraccountants.co.uk',
#  'http://www.bainesjewitt.co.uk',
#  'http://www.guywalmsley.co.uk',
#  'http://www.helmores.co.uk',
#  'http://www.championgroup.co.uk',
#  'http://www.francisclark.co.uk',
#  'http://www.jonesco.co.uk',
#  'http://www.sawhneyconsulting.co.uk',
#  'http://www.granitemorgansmith.co.uk',
#  'http://www.flanagans.weebly.com',
#  'http://www.uttridge-accounting.co.uk',
#  'http://www.michaelkingaccountants.com',
#  'http://www.clearwaterinternational.com',
#  'http://www.watts-gregory.co.uk',
#  'http://www.freemanco.net',
#  'http://www.fraserwood.co.uk',
#  'http://www.champconsultants.co.uk',
#  'http://www.dssbh.co.uk',
#  'http://www.breezeassociates.com',
#  'http://www.heywoodshepherd.co.uk',
#  'http://www.sterlingfinance.net',
#  'http://www.mph4recovery.com',
#  'http://www.c-todd.co.uk',
#  'http://www.proaccountsuk.com',
#  'http://www.srfrancis.co.uk',
#  'http://www.accountax-solutions.co.uk',
#  'http://www.banksco.co.uk',
#  'http://www.lambert-chapman.co.uk',
#  'http://www.millerroskell.co.uk',
#  'http://www.cdaccounts.com',
#  'http://www.aldenandco.co.uk',
#  'http://www.cd-ltd.co.uk',
#  'http://www.hpslimited.co.uk',
#  'http://www.herbertparnell.com',
#  'http://www.kingsleyandco.co.uk',
#  'http://www.montpelierchartered.com',
#  'http://www.adrianco.com',
#  'http://www.butterworthsaccountants.co.uk',
#  'http://www.gardnersaccountants.co.uk',
#  'http://www.searsmorgan.co.uk',
#  'http://www.michaelgeorge-accountants.com',
#  'http://www.wheelerbrown.co.uk',
#  'http://www.accountants-brighton.co.uk',
#  'http://www.cantelowes.co.uk',
#  'http://www.ergrove.co.uk',
#  'http://www.brgbs.com',
#  'http://www.amcas.co.uk',
#  'http://www.wasley-chapman.co.uk',
#  'http://www.accordaccountantscf.co.uk',
#  'http://www.cheshams.com',
#  'http://www.accountantinportsmouth.co.uk',
#  'http://www.atkinsferrie.co.uk',
#  'http://www.jamesmercy.co.uk',
#  'http://www.davidhoward.co.uk',
#  'http://www.asbusiness.co.uk',
#  'http://www.chartax.biz',
#  'http://www.fraserrussell.com',
#  'http://www.stopfords.co.uk',
#  'http://www.payne-accountancy.co.uk',
#  'http://www.freemancarr.com',
#  'http://www.beeverstruthers.co.uk',
#  'http://www.couchmanlee.co.uk',
#  'http://www.buttandco.com',
#  'http://www.deanhowardco.com',
#  'http://www.carterandco.co.uk',
#  'http://www.kkranjan.com',
#  'http://www.spurlingcannon.co.uk',
#  'http://www.sadlertalbot.co.uk',
#  'http://www.taxassist.co.uk',
#  'http://www.keymerhaslam.co.uk',
#  'http://www.lawrenceandcompany.co.uk',
#  'http://www.beresfordaccountants.com',
#  'http://www.pennyweights.co.uk',
#  'http://www.leviroyce.co.uk',
#  'http://www.ghld.uk.com',
#  'http://www.accountsline.eu',
#  'http://www.hakimfry.co.uk',
#  'http://www.pgtax.co.uk',
#  'http://www.financedept.biz',
#  'http://www.morethanaccounts.co.uk',
#  'http://www.thomasandyoung.co.uk',
#  'http://www.hickesonboyce.co.uk',
#  'http://www.accounttaxltd.com']
