# %% [markdown]
# <h1>ACCA Webscraping Firms</h1>
#
# This jupyter notebook contains the code used to webscrape ACCA Firms

# %% [markdown]
# <h2>Importing webscraping libraries</h2>

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# <h2>Defining the Webscraping Spider</h2>
#
# This code block is defining what our web spider will do - note that it isn't running it, just defining it. See that we are extending the exsiting scrapy.Spider class rather than doing everything from scratch, so we only have minimal coding to do.
#
# We tested this code using one page:
#
# http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=2&resultsperpage=100&requestcount=2&hid=
#
# ACCA are helpful enough to return the entire details of a firm as the search result, so parsing is the only real issue. It would only take 84 requests to get the details of all firms.

# %%
class MySpider(scrapy.Spider):
    name = "ACCA"

    custom_settings = {
        'DOWNLOAD_DELAY': 60,
    }
    
    def start_requests(self):
        
        urls = []
                
        for i in range(1,85):
            url = 'http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber='+str(i)+'&resultsperpage=100&requestcount='+str(i)+'&hid='
            urls.append(url)
        
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)
            
    def parse(self, response):
        
        page_link = response.xpath('//tr//@id | //tr//h5//a//@href').extract()
        name = response.xpath('//tr//@id | //tr//h5//a/text()').extract()
        address = response.xpath('//tr//@id | //tr//td/text()').extract()
        telephone = response.xpath('//tr//@id | //tr//ul//li[last()]//text()').extract()
        email_website = response.xpath('//tr//@id | //tr//ul//li//@href').extract()
        expertise = response.xpath('//tr//@id | //tr[@class="expandable"]//text()').extract()

        firm_page_link = [' '.join(a.replace('\n', ' ').replace('\t', ' ').replace('\r', ' ').split()) for a in page_link]
        firm_name = [' '.join(a.replace('\n', ' ').replace('\t', ' ').replace('\r', ' ').split()) for a in name]
        firm_address = [' '.join(a.replace('\n', ' ').replace('\t', ' ').replace('\r', ' ').split()) for a in address]
        firm_telephone = [' '.join(a.replace('\n', ' ').replace('\t', ' ').replace('\r', ' ').split()) for a in telephone]
        firm_email_website = [' '.join(a.replace('\n', ' ').replace('\t', ' ').replace('\r', ' ').split()) for a in email_website]
        firm_expertise = [' '.join(a.replace('\n', ' ').replace('\t', ' ').replace('\r', ' ').split()) for a in expertise]
        
        full_pl_output.append(firm_page_link)
        full_nm_output.append(firm_name)
        full_ad_output.append(firm_address)
        full_tp_output.append(firm_telephone)
        full_ew_output.append(firm_email_website)
        full_ex_output.append(firm_expertise)

# %% [markdown]
# <h2>Running the Webscraping</h2>
#
# Note, you can't re run the code below in a single session for one reason or another, so you need to restart the kernel between runs.
#
# This code creates a lightweight container for our webspider and then runs it - to be honest understanding this is probably optional unless it breaks.

# %%
full_pl_output = []
full_nm_output = []
full_ad_output = []
full_tp_output = []
full_ew_output = []
full_ex_output = []

process = CrawlerProcess()
process.crawl(MySpider)
process.start()
# Out:
# 2017-09-23 08:17:14 [scrapy.utils.log] INFO: Scrapy 1.3.3 started (bot: scrapybot)
# 2017-09-23 08:17:14 [scrapy.utils.log] INFO: Overridden settings: {}
# 2017-09-23 08:17:14 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2017-09-23 08:17:14 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2017-09-23 08:17:14 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2017-09-23 08:17:14 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2017-09-23 08:17:14 [scrapy.core.engine] INFO: Spider opened
# 2017-09-23 08:17:14 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:17:14 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6042
# 2017-09-23 08:17:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=1&resultsperpage=100&requestcount=1&hid=> (referer: None)
# 2017-09-23 08:18:14 [scrapy.extensions.logstats] INFO: Crawled 1 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:18:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=2&resultsperpage=100&requestcount=2&hid=> (referer: None)
# 2017-09-23 08:19:14 [scrapy.extensions.logstats] INFO: Crawled 2 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=3&resultsperpage=100&requestcount=3&hid=> (referer: None)
# 2017-09-23 08:20:14 [scrapy.extensions.logstats] INFO: Crawled 3 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:20:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=4&resultsperpage=100&requestcount=4&hid=> (referer: None)
# 2017-09-23 08:21:14 [scrapy.extensions.logstats] INFO: Crawled 4 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:21:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=5&resultsperpage=100&requestcount=5&hid=> (referer: None)
# 2017-09-23 08:22:14 [scrapy.extensions.logstats] INFO: Crawled 5 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:23:14 [scrapy.extensions.logstats] INFO: Crawled 5 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:23:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=6&resultsperpage=100&requestcount=6&hid=> (referer: None)
# 2017-09-23 08:24:14 [scrapy.extensions.logstats] INFO: Crawled 6 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:24:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=7&resultsperpage=100&requestcount=7&hid=> (referer: None)
# 2017-09-23 08:25:14 [scrapy.extensions.logstats] INFO: Crawled 7 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:25:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=8&resultsperpage=100&requestcount=8&hid=> (referer: None)
# 2017-09-23 08:26:14 [scrapy.extensions.logstats] INFO: Crawled 8 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:26:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=9&resultsperpage=100&requestcount=9&hid=> (referer: None)
# 2017-09-23 08:27:14 [scrapy.extensions.logstats] INFO: Crawled 9 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:27:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=10&resultsperpage=100&requestcount=10&hid=> (referer: None)
# 2017-09-23 08:28:14 [scrapy.extensions.logstats] INFO: Crawled 10 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:29:14 [scrapy.extensions.logstats] INFO: Crawled 10 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:29:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=11&resultsperpage=100&requestcount=11&hid=> (referer: None)
# 2017-09-23 08:30:14 [scrapy.extensions.logstats] INFO: Crawled 11 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:30:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=12&resultsperpage=100&requestcount=12&hid=> (referer: None)
# 2017-09-23 08:31:14 [scrapy.extensions.logstats] INFO: Crawled 12 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:32:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=13&resultsperpage=100&requestcount=13&hid=> (referer: None)
# 2017-09-23 08:32:14 [scrapy.extensions.logstats] INFO: Crawled 13 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:32:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=14&resultsperpage=100&requestcount=14&hid=> (referer: None)
# 2017-09-23 08:33:14 [scrapy.extensions.logstats] INFO: Crawled 14 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:34:14 [scrapy.extensions.logstats] INFO: Crawled 14 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:34:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=15&resultsperpage=100&requestcount=15&hid=> (referer: None)
# 2017-09-23 08:35:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=16&resultsperpage=100&requestcount=16&hid=> (referer: None)
# 2017-09-23 08:35:14 [scrapy.extensions.logstats] INFO: Crawled 16 pages (at 2 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:36:14 [scrapy.extensions.logstats] INFO: Crawled 16 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:36:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=17&resultsperpage=100&requestcount=17&hid=> (referer: None)
# 2017-09-23 08:37:14 [scrapy.extensions.logstats] INFO: Crawled 17 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:37:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=18&resultsperpage=100&requestcount=18&hid=> (referer: None)
# 2017-09-23 08:38:14 [scrapy.extensions.logstats] INFO: Crawled 18 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:38:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=19&resultsperpage=100&requestcount=19&hid=> (referer: None)
# 2017-09-23 08:39:14 [scrapy.extensions.logstats] INFO: Crawled 19 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:40:14 [scrapy.extensions.logstats] INFO: Crawled 19 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:40:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=20&resultsperpage=100&requestcount=20&hid=> (referer: None)
# 2017-09-23 08:41:14 [scrapy.extensions.logstats] INFO: Crawled 20 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:41:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=21&resultsperpage=100&requestcount=21&hid=> (referer: None)
# 2017-09-23 08:42:14 [scrapy.extensions.logstats] INFO: Crawled 21 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:43:14 [scrapy.extensions.logstats] INFO: Crawled 21 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:43:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=22&resultsperpage=100&requestcount=22&hid=> (referer: None)
# 2017-09-23 08:44:14 [scrapy.extensions.logstats] INFO: Crawled 22 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:44:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=23&resultsperpage=100&requestcount=23&hid=> (referer: None)
# 2017-09-23 08:45:14 [scrapy.extensions.logstats] INFO: Crawled 23 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:45:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=24&resultsperpage=100&requestcount=24&hid=> (referer: None)
# 2017-09-23 08:46:14 [scrapy.extensions.logstats] INFO: Crawled 24 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:47:14 [scrapy.extensions.logstats] INFO: Crawled 24 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:47:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=25&resultsperpage=100&requestcount=25&hid=> (referer: None)
# 2017-09-23 08:48:14 [scrapy.extensions.logstats] INFO: Crawled 25 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:48:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=26&resultsperpage=100&requestcount=26&hid=> (referer: None)
# 2017-09-23 08:49:14 [scrapy.extensions.logstats] INFO: Crawled 26 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:49:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=27&resultsperpage=100&requestcount=27&hid=> (referer: None)
# 2017-09-23 08:50:14 [scrapy.extensions.logstats] INFO: Crawled 27 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:50:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=28&resultsperpage=100&requestcount=28&hid=> (referer: None)
# 2017-09-23 08:51:14 [scrapy.extensions.logstats] INFO: Crawled 28 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:52:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=29&resultsperpage=100&requestcount=29&hid=> (referer: None)
# 2017-09-23 08:52:14 [scrapy.extensions.logstats] INFO: Crawled 29 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:53:14 [scrapy.extensions.logstats] INFO: Crawled 29 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:53:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=30&resultsperpage=100&requestcount=30&hid=> (referer: None)
# 2017-09-23 08:54:14 [scrapy.extensions.logstats] INFO: Crawled 30 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:54:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=31&resultsperpage=100&requestcount=31&hid=> (referer: None)
# 2017-09-23 08:55:14 [scrapy.extensions.logstats] INFO: Crawled 31 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=32&resultsperpage=100&requestcount=32&hid=> (referer: None)
# 2017-09-23 08:56:14 [scrapy.extensions.logstats] INFO: Crawled 32 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:56:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=33&resultsperpage=100&requestcount=33&hid=> (referer: None)
# 2017-09-23 08:57:14 [scrapy.extensions.logstats] INFO: Crawled 33 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:57:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=34&resultsperpage=100&requestcount=34&hid=> (referer: None)
# 2017-09-23 08:58:14 [scrapy.extensions.logstats] INFO: Crawled 34 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 08:59:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=35&resultsperpage=100&requestcount=35&hid=> (referer: None)
# 2017-09-23 08:59:14 [scrapy.extensions.logstats] INFO: Crawled 35 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:00:14 [scrapy.extensions.logstats] INFO: Crawled 35 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:00:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=36&resultsperpage=100&requestcount=36&hid=> (referer: None)
# 2017-09-23 09:01:14 [scrapy.extensions.logstats] INFO: Crawled 36 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:01:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=37&resultsperpage=100&requestcount=37&hid=> (referer: None)
# 2017-09-23 09:02:14 [scrapy.extensions.logstats] INFO: Crawled 37 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:02:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=38&resultsperpage=100&requestcount=38&hid=> (referer: None)
# 2017-09-23 09:03:14 [scrapy.extensions.logstats] INFO: Crawled 38 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:04:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=39&resultsperpage=100&requestcount=39&hid=> (referer: None)
# 2017-09-23 09:04:14 [scrapy.extensions.logstats] INFO: Crawled 39 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:04:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=40&resultsperpage=100&requestcount=40&hid=> (referer: None)
# 2017-09-23 09:05:14 [scrapy.extensions.logstats] INFO: Crawled 40 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:06:14 [scrapy.extensions.logstats] INFO: Crawled 40 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:06:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=41&resultsperpage=100&requestcount=41&hid=> (referer: None)
# 2017-09-23 09:07:14 [scrapy.extensions.logstats] INFO: Crawled 41 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:07:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=42&resultsperpage=100&requestcount=42&hid=> (referer: None)
# 2017-09-23 09:08:14 [scrapy.extensions.logstats] INFO: Crawled 42 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:08:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=43&resultsperpage=100&requestcount=43&hid=> (referer: None)
# 2017-09-23 09:09:14 [scrapy.extensions.logstats] INFO: Crawled 43 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:10:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=44&resultsperpage=100&requestcount=44&hid=> (referer: None)
# 2017-09-23 09:10:14 [scrapy.extensions.logstats] INFO: Crawled 44 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:11:14 [scrapy.extensions.logstats] INFO: Crawled 44 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:11:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=45&resultsperpage=100&requestcount=45&hid=> (referer: None)
# 2017-09-23 09:12:14 [scrapy.extensions.logstats] INFO: Crawled 45 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:12:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=46&resultsperpage=100&requestcount=46&hid=> (referer: None)
# 2017-09-23 09:13:14 [scrapy.extensions.logstats] INFO: Crawled 46 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:14:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=47&resultsperpage=100&requestcount=47&hid=> (referer: None)
# 2017-09-23 09:14:14 [scrapy.extensions.logstats] INFO: Crawled 47 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:15:14 [scrapy.extensions.logstats] INFO: Crawled 47 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:15:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=48&resultsperpage=100&requestcount=48&hid=> (referer: None)
# 2017-09-23 09:16:14 [scrapy.extensions.logstats] INFO: Crawled 48 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:16:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=49&resultsperpage=100&requestcount=49&hid=> (referer: None)
# 2017-09-23 09:17:14 [scrapy.extensions.logstats] INFO: Crawled 49 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:18:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=50&resultsperpage=100&requestcount=50&hid=> (referer: None)
# 2017-09-23 09:18:14 [scrapy.extensions.logstats] INFO: Crawled 50 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:19:14 [scrapy.extensions.logstats] INFO: Crawled 50 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:19:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=51&resultsperpage=100&requestcount=51&hid=> (referer: None)
# 2017-09-23 09:20:14 [scrapy.extensions.logstats] INFO: Crawled 51 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:20:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=52&resultsperpage=100&requestcount=52&hid=> (referer: None)
# 2017-09-23 09:21:14 [scrapy.extensions.logstats] INFO: Crawled 52 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:21:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=53&resultsperpage=100&requestcount=53&hid=> (referer: None)
# 2017-09-23 09:22:14 [scrapy.extensions.logstats] INFO: Crawled 53 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:23:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=54&resultsperpage=100&requestcount=54&hid=> (referer: None)
# 2017-09-23 09:23:14 [scrapy.extensions.logstats] INFO: Crawled 54 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:23:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=55&resultsperpage=100&requestcount=55&hid=> (referer: None)
# 2017-09-23 09:24:14 [scrapy.extensions.logstats] INFO: Crawled 55 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:24:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=56&resultsperpage=100&requestcount=56&hid=> (referer: None)
# 2017-09-23 09:25:14 [scrapy.extensions.logstats] INFO: Crawled 56 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:26:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=57&resultsperpage=100&requestcount=57&hid=> (referer: None)
# 2017-09-23 09:26:14 [scrapy.extensions.logstats] INFO: Crawled 57 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:27:14 [scrapy.extensions.logstats] INFO: Crawled 57 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:27:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=58&resultsperpage=100&requestcount=58&hid=> (referer: None)
# 2017-09-23 09:28:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=59&resultsperpage=100&requestcount=59&hid=> (referer: None)
# 2017-09-23 09:28:14 [scrapy.extensions.logstats] INFO: Crawled 59 pages (at 2 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:29:14 [scrapy.extensions.logstats] INFO: Crawled 59 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:29:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=60&resultsperpage=100&requestcount=60&hid=> (referer: None)
# 2017-09-23 09:30:14 [scrapy.extensions.logstats] INFO: Crawled 60 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:30:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=61&resultsperpage=100&requestcount=61&hid=> (referer: None)
# 2017-09-23 09:31:14 [scrapy.extensions.logstats] INFO: Crawled 61 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:31:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=62&resultsperpage=100&requestcount=62&hid=> (referer: None)
# 2017-09-23 09:32:14 [scrapy.extensions.logstats] INFO: Crawled 62 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:32:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=63&resultsperpage=100&requestcount=63&hid=> (referer: None)
# 2017-09-23 09:33:14 [scrapy.extensions.logstats] INFO: Crawled 63 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:34:14 [scrapy.extensions.logstats] INFO: Crawled 63 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:34:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=64&resultsperpage=100&requestcount=64&hid=> (referer: None)
# 2017-09-23 09:35:14 [scrapy.extensions.logstats] INFO: Crawled 64 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:35:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=65&resultsperpage=100&requestcount=65&hid=> (referer: None)
# 2017-09-23 09:36:14 [scrapy.extensions.logstats] INFO: Crawled 65 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:37:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=66&resultsperpage=100&requestcount=66&hid=> (referer: None)
# 2017-09-23 09:37:14 [scrapy.extensions.logstats] INFO: Crawled 66 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:38:14 [scrapy.extensions.logstats] INFO: Crawled 66 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:38:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=67&resultsperpage=100&requestcount=67&hid=> (referer: None)
# 2017-09-23 09:39:14 [scrapy.extensions.logstats] INFO: Crawled 67 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:39:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=68&resultsperpage=100&requestcount=68&hid=> (referer: None)
# 2017-09-23 09:40:14 [scrapy.extensions.logstats] INFO: Crawled 68 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:40:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=69&resultsperpage=100&requestcount=69&hid=> (referer: None)
# 2017-09-23 09:41:14 [scrapy.extensions.logstats] INFO: Crawled 69 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:41:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=70&resultsperpage=100&requestcount=70&hid=> (referer: None)
# 2017-09-23 09:42:14 [scrapy.extensions.logstats] INFO: Crawled 70 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:42:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=71&resultsperpage=100&requestcount=71&hid=> (referer: None)
# 2017-09-23 09:43:14 [scrapy.extensions.logstats] INFO: Crawled 71 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:44:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=72&resultsperpage=100&requestcount=72&hid=> (referer: None)
# 2017-09-23 09:44:14 [scrapy.extensions.logstats] INFO: Crawled 72 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:45:14 [scrapy.extensions.logstats] INFO: Crawled 72 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:45:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=73&resultsperpage=100&requestcount=73&hid=> (referer: None)
# 2017-09-23 09:46:14 [scrapy.extensions.logstats] INFO: Crawled 73 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:46:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=74&resultsperpage=100&requestcount=74&hid=> (referer: None)
# 2017-09-23 09:47:14 [scrapy.extensions.logstats] INFO: Crawled 74 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:48:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=75&resultsperpage=100&requestcount=75&hid=> (referer: None)
# 2017-09-23 09:48:14 [scrapy.extensions.logstats] INFO: Crawled 75 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:49:14 [scrapy.extensions.logstats] INFO: Crawled 75 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:49:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=76&resultsperpage=100&requestcount=76&hid=> (referer: None)
# 2017-09-23 09:50:14 [scrapy.extensions.logstats] INFO: Crawled 76 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:50:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=77&resultsperpage=100&requestcount=77&hid=> (referer: None)
# 2017-09-23 09:51:14 [scrapy.extensions.logstats] INFO: Crawled 77 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:52:14 [scrapy.extensions.logstats] INFO: Crawled 77 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:52:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=78&resultsperpage=100&requestcount=78&hid=> (referer: None)
# 2017-09-23 09:53:14 [scrapy.extensions.logstats] INFO: Crawled 78 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:53:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=79&resultsperpage=100&requestcount=79&hid=> (referer: None)
# 2017-09-23 09:54:14 [scrapy.extensions.logstats] INFO: Crawled 79 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:54:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=80&resultsperpage=100&requestcount=80&hid=> (referer: None)
# 2017-09-23 09:55:14 [scrapy.extensions.logstats] INFO: Crawled 80 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:56:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=81&resultsperpage=100&requestcount=81&hid=> (referer: None)
# 2017-09-23 09:56:14 [scrapy.extensions.logstats] INFO: Crawled 81 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:56:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=82&resultsperpage=100&requestcount=82&hid=> (referer: None)
# 2017-09-23 09:57:14 [scrapy.extensions.logstats] INFO: Crawled 82 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:57:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=83&resultsperpage=100&requestcount=83&hid=> (referer: None)
# 2017-09-23 09:58:14 [scrapy.extensions.logstats] INFO: Crawled 83 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2017-09-23 09:58:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.accaglobal.com/uk/en/member/find-an-accountant/find-firm/results.html?isocountry=GB&location=&country=UK&firmname=&organisationid=ACCA&pagenumber=84&resultsperpage=100&requestcount=84&hid=> (referer: None)
# 2017-09-23 09:58:54 [scrapy.core.engine] INFO: Closing spider (finished)
# 2017-09-23 09:58:54 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 40718,
#  'downloader/request_count': 84,
#  'downloader/request_method_count/GET': 84,
#  'downloader/response_bytes': 2337621,
#  'downloader/response_count': 84,
#  'downloader/response_status_count/200': 84,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2017, 9, 23, 8, 58, 54, 107792),
#  'log_count/DEBUG': 85,
#  'log_count/INFO': 108,
#  'response_received_count': 84,
#  'scheduler/dequeued': 84,
#  'scheduler/dequeued/memory': 84,
#  'scheduler/enqueued': 84,
#  'scheduler/enqueued/memory': 84,
#  'start_time': datetime.datetime(2017, 9, 23, 7, 17, 14, 374302)}
# 2017-09-23 09:58:54 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# We've now downloaded all the pages that we want to scrape. The first thing to do is to examine what we got back

# %%
final_pl_output = []
final_nm_output = []
final_ad_output = []
final_tp_output = []
final_ew_output = []
final_ex_output = []

for i in range(len(full_pl_output)):
    for j in range(len(full_pl_output[i])):
        final_pl_output.append(full_pl_output[i][j].encode('ascii','replace'))
        
for i in range(len(full_nm_output)):
    for j in range(len(full_nm_output[i])):
        final_nm_output.append(full_nm_output[i][j].encode('ascii','replace'))

for i in range(len(full_ad_output)):
    for j in range(len(full_ad_output[i])):
        final_ad_output.append(full_ad_output[i][j].encode('ascii','replace'))
        
for i in range(len(full_tp_output)):
    for j in range(len(full_tp_output[i])):
        final_tp_output.append(full_tp_output[i][j].encode('ascii','replace'))
        
for i in range(len(full_ew_output)):
    for j in range(len(full_ew_output[i])):
        final_ew_output.append(full_ew_output[i][j].encode('ascii','replace'))

for i in range(len(full_ex_output)):
    for j in range(len(full_ex_output[i])):
        final_ex_output.append(full_ex_output[i][j].encode('ascii','replace'))


#print(final_pl_output[0:4])
#print(final_ad_output[0:20])
#print(final_nm_output[0:4])
#print(final_tp_output)
#print(final_ew_output[0:8])
#print(final_ex_output[0:22])

# %%
row_index_pl = []
row_index_ad = []
row_index_nm = []
row_index_tp = []
row_index_ew = []
row_index_ex = []

for i in range(len(final_pl_output)):
    if "rowId" in final_pl_output[i]:
        row_index_pl.append(i)

for i in range(len(final_nm_output)):
    if "rowId" in final_nm_output[i]:
        row_index_nm.append(i)

for i in range(len(final_ad_output)):
    if "rowId" in final_ad_output[i]:
        row_index_ad.append(i)

for i in range(len(final_tp_output)):
    if "rowId" in final_tp_output[i]:
        row_index_tp.append(i)

for i in range(len(final_ew_output)):
    if "rowId" in final_ew_output[i]:
        row_index_ew.append(i)

for i in range(len(final_ex_output)):
    if "rowId" in final_ex_output[i]:
        row_index_ex.append(i)

# %%
split_output_pl = []
split_output_ad = []
split_output_nm = []
split_output_tp = []
split_output_ew = []
split_output_ex = []

start = 0
for index in row_index_pl[1:]:
    split_output_pl.append(final_pl_output[start+1:index])
    start = index
    
split_output_pl.append(final_pl_output[start+1:])

start = 0
for index in row_index_ad[1:]:
    split_output_ad.append(final_ad_output[start+1:index])
    start = index
    
split_output_ad.append(final_ad_output[start+1:])

start = 0
for index in row_index_nm[1:]:
    split_output_nm.append(final_nm_output[start+1:index])
    start = index
    
split_output_nm.append(final_nm_output[start+1:])

start = 0
for index in row_index_tp[1:]:
    split_output_tp.append(final_tp_output[start+1:index])
    start = index
    
split_output_tp.append(final_tp_output[start+1:])

start = 0
for index in row_index_ew[1:]:
    split_output_ew.append(final_ew_output[start+1:index])
    start = index
    
split_output_ew.append(final_ew_output[start+1:])

start = 0
for index in row_index_ex[1:]:
    split_output_ex.append(final_ex_output[start+1:index])
    start = index
    
split_output_ex.append(final_ex_output[start+1:])

#print(split_output_pl[0:3])
#print(split_output_ad[0:3])
#print(split_output_nm[0:3])
#print(split_output_tp[0:3])
#print(split_output_ew[0:4])
#print(split_output_ex[0:3])

# %%
final_pl = [a[0].split("=")[-1] for a in split_output_pl]

final_nm = []
for a in split_output_nm:
    if a:
        final_nm.append(a[0])
    else:
        final_nm.append("")


final_ad = []   
for i in range(len(split_output_ad)):
    ad = []
    
    for j in range(len(split_output_ad[i])):
        if split_output_ad[i][j]:
            ad.append(split_output_ad[i][j].encode('ascii','replace'))
            
    final_ad.append(ad)

final_pc = []
for i in range(len(final_ad)):   
    final_pc.append(final_ad[i][-1])

final_ad2 = []
for i in range(len(final_ad)):   
    final_ad2.append(final_ad[i][:-1])

for i in final_ad:
    if i:
         final_pc.append(i[-1])
    else:
        final_pc.append("")
        
final_tp = []
for a in split_output_tp:
    if a:
        final_tp.append(a[0])
    else:
        final_tp.append("")

final_em = []
final_ws = []
for a in split_output_ew:
    if a:
        if "mailto" in a[0]:
            if len(a) == 1:
                final_em.append(a[0][7:])
                final_ws.append("")
            else:
                final_em.append(a[0][7:])
                final_ws.append(a[1])
        else:
            final_ws.append(a[0])
            final_em.append("")
    else:
        final_em.append("")
        final_ws.append("")

final_ex = []    
for i in range(len(split_output_ex)):
    ce = []
    for j in range(len(split_output_ex[i])):
        if split_output_ex[i][j]:
            ce.append(split_output_ex[i][j].encode('ascii','replace'))
        final_ex.append(ce)
    else:
        final_ex.append([])

# %%
firms_matrix_ACCA = []

for i in range(len(final_pl)):
    firms_matrix_ACCA.append([final_pl[i],final_nm[i],final_ad2[i],final_pc[i],final_tp[i],final_em[i],final_ws[i],final_ex[i]])

firms_matrix_ACCA.sort()

# %%
print(len(firms_matrix_ACCA))
# Out:
# 8355

# %%
import pickle

pickle.dump(firms_matrix_ACCA, open('/home/de-admin/Documents/Webscraping/ACCA_Firms.p','wb'))

# %% [markdown]
# How to get pickled data back:
#
# import pickle
#
# output = pickle.load(open('/home/de-admin/Documents/Webscraping/ACCA_Firms.p','rb'))
